# %% [markdown]
# # The Great Red Spot
#
# Jupiter’s iconic Great Red Spot (GRS) is actually an enormous storm that is bigger than Earth that has raged for hundreds of years! {numref}`great-red-spot` below shows an image of Jupiter captured by the Hubble Space Telescope on June 27, 2019.
#
# ```{figure} https://solarsystem.nasa.gov/system/resources/detail_files/626_PIA21775.jpg
# ---
# height: 300px
# name: great-red-spot
# ---
# Jupiter's Great Red Spot! Source: [NASA](https://solarsystem.nasa.gov/resources/626/jupiters-great-red-spot-in-true-color/?category=planets_jupiter).
# ```
#
# Jupiter's GRS has been observed to be shrinking for about the last century and a half! [Here](https://github.com/UBC-DSCI/jupyterdays/tree/master/jupyterdays/sessions/beuzen/data) is some data of the length of the GRS spanning the last ~150 years which we can use to investigate this phenomenon.

# %%
import pandas as pd
pd.options.plotting.backend = "plotly"

url = "https://raw.githubusercontent.com/UBC-DSCI/jupyterdays/master/jupyterdays/sessions/beuzen/data/GRS_data.csv"
df = pd.read_csv(url)
df['Year'] = df['Year'].astype(int) 
df.head()
# Out:
#   Recorder  Year  GRS Length
# 0    Reese  1880        38.6
# 1    Reese  1882        38.5
# 2    Reese  1885        38.5
# 3    Reese  1887        38.3
# 4    Reese  1890        38.0

# %%
import plotly.io as pio
pio.renderers.default = "sphinx_gallery_png"
fig = df.plot.scatter(x="Year", y="GRS Length", color="Recorder",
                      range_x=[1870, 2030], range_y=[10, 40],
                      width=650, height=400)
fig.update_layout(title={'text': "Great Red Spot Size", 'x':0.5, 'y':0.92})
fig.update_traces(marker=dict(size=7))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# /usr/local/lib/python3.6/dist-packages/plotly/basedatatypes.py in _ipython_display_(self)
#     842
#     843         if pio.renderers.render_on_display and pio.renderers.default:
# --> 844             pio.show(self)
#     845         else:
#     846             print(repr(self))
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     402
#     403     # external renderers
# --> 404     renderers._perform_external_rendering(fig_dict, renderers_string=renderer, **kwargs)
#     405
#     406
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_renderers.py in _perform_external_rendering(self, fig_dict, renderers_string, **kwargs)
#     339                         setattr(renderer, k, v)
#     340
# --> 341                 renderer.render(fig_dict)
#     342
#     343
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_base_renderers.py in render(self, fig_dict)
#     862         filename_png = filename_root + ".png"
#     863         figure = return_figure_from_figure_or_data(fig_dict, True)
# --> 864         _ = write_html(fig_dict, file=filename_html, include_plotlyjs="cdn")
#     865         try:
#     866             write_image(figure, filename_png)
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_html.py in write_html(fig, file, config, auto_play, include_plotlyjs, include_mathjax, post_script, full_html, animation_opts, validate, default_width, default_height, auto_open)
#     525     # Write HTML string
#     526     if file_is_str:
# --> 527         with open(file, "w") as f:
#     528             f.write(html_str)
#     529     else:
#
# PermissionError: [Errno 13] Permission denied: '/usr/local/lib/python3.6/dist-packages/plotly/basedatatypes.html'
# Figure({
#     'data': [{'hovertemplate': 'Recorder=Reese<br>Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#               'legendgroup': 'Reese',
#               'marker': {'color': '#636efa', 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Reese',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([1880, 1882, 1885, 1887, 1890, 1892, 1895, 1897, 1900, 1902, 1905, 1907,
#                           1910, 1912, 1915, 1917, 1920, 1922, 1925, 1927, 1930, 1932, 1935, 1937,
#                           1940, 1942, 1945, 1947, 1950, 1952, 1955, 1957, 1960, 1962, 1965]),
#               'xaxis': 'x',
#               'y': array([38.6, 38.5, 38.5, 38.3, 38. , 37.4, 36.6, 36. , 35.3, 34.7, 34.3, 33.9,
#                           33.6, 33.8, 34.4, 35.3, 36.1, 36.5, 36.5, 35.7, 34.4, 33.2, 32.2, 31.5,
#                           30.8, 30.3, 29.8, 29.5, 29.5, 29.5, 29.5, 29.2, 28.7, 28. , 27.3]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Recorder=Guitar<br>Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#               'legendgroup': 'Guitar',
#               'marker': {'color': '#EF553B', 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Guitar',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([1962, 1963, 1964, 1965, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974,
#                           1975, 1976, 1978, 1979, 1980]),
#               'xaxis': 'x',
#               'y': array([25.1, 24.3, 24.2, 23.7, 25.9, 24.7, 24.8, 24.9, 24.4, 23.1, 21.9, 22.7,
#                           21.4, 21.7, 23.7, 24.8, 23.3]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Recorder=Spacecraft<br>Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#               'legendgroup': 'Spacecraft',
#               'marker': {'color': '#00cc96', 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Spacecraft',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([1979, 1994, 1994, 1994, 1995, 1995, 1996, 1996, 1997, 1999, 2001, 2007,
#                           2008, 2008, 2008, 2009, 2009, 2012, 2014, 2015, 2016, 2016, 2017, 2017,
#                           2017]),
#               'xaxis': 'x',
#               'y': array([20.9 , 18.17, 18.2 , 17.8 , 18.3 , 18.4 , 17.7 , 18.5 , 17.2 , 17.9 ,
#                           17.4 , 16.3 , 15.8 , 15.6 , 15.6 , 15.4 , 15.2 , 15.3 , 14.1 , 14.  ,
#                           13.7 , 13.6 , 14.  , 13.9 , 14.  ]),
#               'yaxis': 'y'}],
#     'layout': {'height': 400,
#                'legend': {'title': {'text': 'Recorder'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'title': {'text': 'Great Red Spot Size', 'x': 0.5, 'y': 0.92},
#                'width': 650,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'range': [1870, 2030], 'title': {'text': 'Year'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'range': [10, 40], 'title': {'text': 'GRS Length'}}}
# })

# %%
fig = df.plot.scatter(x="Year", y="GRS Length",
                      animation_frame="Year",
                      range_x=[1870, 2030], range_y=[10, 40],
                      width=600, height=520)
fig.update_layout(title={'text': "Great Red Spot Size Animation", 'x':0.5, 'y':0.94})
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 200
fig.update_traces(marker=dict(size=10))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# /usr/local/lib/python3.6/dist-packages/plotly/basedatatypes.py in _ipython_display_(self)
#     842
#     843         if pio.renderers.render_on_display and pio.renderers.default:
# --> 844             pio.show(self)
#     845         else:
#     846             print(repr(self))
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     402
#     403     # external renderers
# --> 404     renderers._perform_external_rendering(fig_dict, renderers_string=renderer, **kwargs)
#     405
#     406
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_renderers.py in _perform_external_rendering(self, fig_dict, renderers_string, **kwargs)
#     339                         setattr(renderer, k, v)
#     340
# --> 341                 renderer.render(fig_dict)
#     342
#     343
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_base_renderers.py in render(self, fig_dict)
#     862         filename_png = filename_root + ".png"
#     863         figure = return_figure_from_figure_or_data(fig_dict, True)
# --> 864         _ = write_html(fig_dict, file=filename_html, include_plotlyjs="cdn")
#     865         try:
#     866             write_image(figure, filename_png)
#
# /usr/local/lib/python3.6/dist-packages/plotly/io/_html.py in write_html(fig, file, config, auto_play, include_plotlyjs, include_mathjax, post_script, full_html, animation_opts, validate, default_width, default_height, auto_open)
#     525     # Write HTML string
#     526     if file_is_str:
# --> 527         with open(file, "w") as f:
#     528             f.write(html_str)
#     529     else:
#
# PermissionError: [Errno 13] Permission denied: '/usr/local/lib/python3.6/dist-packages/plotly/basedatatypes.html'
# Figure({
#     'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array([1880]),
#               'xaxis': 'x',
#               'y': array([38.6]),
#               'yaxis': 'y'}],
#     'frames': [{'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1880]),
#                           'xaxis': 'x',
#                           'y': array([38.6]),
#                           'yaxis': 'y'}],
#                 'name': '1880'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1882]),
#                           'xaxis': 'x',
#                           'y': array([38.5]),
#                           'yaxis': 'y'}],
#                 'name': '1882'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1885]),
#                           'xaxis': 'x',
#                           'y': array([38.5]),
#                           'yaxis': 'y'}],
#                 'name': '1885'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1887]),
#                           'xaxis': 'x',
#                           'y': array([38.3]),
#                           'yaxis': 'y'}],
#                 'name': '1887'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1890]),
#                           'xaxis': 'x',
#                           'y': array([38.]),
#                           'yaxis': 'y'}],
#                 'name': '1890'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1892]),
#                           'xaxis': 'x',
#                           'y': array([37.4]),
#                           'yaxis': 'y'}],
#                 'name': '1892'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1895]),
#                           'xaxis': 'x',
#                           'y': array([36.6]),
#                           'yaxis': 'y'}],
#                 'name': '1895'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1897]),
#                           'xaxis': 'x',
#                           'y': array([36.]),
#                           'yaxis': 'y'}],
#                 'name': '1897'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1900]),
#                           'xaxis': 'x',
#                           'y': array([35.3]),
#                           'yaxis': 'y'}],
#                 'name': '1900'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1902]),
#                           'xaxis': 'x',
#                           'y': array([34.7]),
#                           'yaxis': 'y'}],
#                 'name': '1902'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1905]),
#                           'xaxis': 'x',
#                           'y': array([34.3]),
#                           'yaxis': 'y'}],
#                 'name': '1905'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1907]),
#                           'xaxis': 'x',
#                           'y': array([33.9]),
#                           'yaxis': 'y'}],
#                 'name': '1907'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1910]),
#                           'xaxis': 'x',
#                           'y': array([33.6]),
#                           'yaxis': 'y'}],
#                 'name': '1910'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1912]),
#                           'xaxis': 'x',
#                           'y': array([33.8]),
#                           'yaxis': 'y'}],
#                 'name': '1912'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1915]),
#                           'xaxis': 'x',
#                           'y': array([34.4]),
#                           'yaxis': 'y'}],
#                 'name': '1915'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1917]),
#                           'xaxis': 'x',
#                           'y': array([35.3]),
#                           'yaxis': 'y'}],
#                 'name': '1917'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1920]),
#                           'xaxis': 'x',
#                           'y': array([36.1]),
#                           'yaxis': 'y'}],
#                 'name': '1920'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1922]),
#                           'xaxis': 'x',
#                           'y': array([36.5]),
#                           'yaxis': 'y'}],
#                 'name': '1922'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1925]),
#                           'xaxis': 'x',
#                           'y': array([36.5]),
#                           'yaxis': 'y'}],
#                 'name': '1925'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1927]),
#                           'xaxis': 'x',
#                           'y': array([35.7]),
#                           'yaxis': 'y'}],
#                 'name': '1927'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1930]),
#                           'xaxis': 'x',
#                           'y': array([34.4]),
#                           'yaxis': 'y'}],
#                 'name': '1930'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1932]),
#                           'xaxis': 'x',
#                           'y': array([33.2]),
#                           'yaxis': 'y'}],
#                 'name': '1932'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1935]),
#                           'xaxis': 'x',
#                           'y': array([32.2]),
#                           'yaxis': 'y'}],
#                 'name': '1935'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1937]),
#                           'xaxis': 'x',
#                           'y': array([31.5]),
#                           'yaxis': 'y'}],
#                 'name': '1937'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1940]),
#                           'xaxis': 'x',
#                           'y': array([30.8]),
#                           'yaxis': 'y'}],
#                 'name': '1940'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1942]),
#                           'xaxis': 'x',
#                           'y': array([30.3]),
#                           'yaxis': 'y'}],
#                 'name': '1942'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1945]),
#                           'xaxis': 'x',
#                           'y': array([29.8]),
#                           'yaxis': 'y'}],
#                 'name': '1945'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1947]),
#                           'xaxis': 'x',
#                           'y': array([29.5]),
#                           'yaxis': 'y'}],
#                 'name': '1947'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1950]),
#                           'xaxis': 'x',
#                           'y': array([29.5]),
#                           'yaxis': 'y'}],
#                 'name': '1950'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1952]),
#                           'xaxis': 'x',
#                           'y': array([29.5]),
#                           'yaxis': 'y'}],
#                 'name': '1952'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1955]),
#                           'xaxis': 'x',
#                           'y': array([29.5]),
#                           'yaxis': 'y'}],
#                 'name': '1955'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1957]),
#                           'xaxis': 'x',
#                           'y': array([29.2]),
#                           'yaxis': 'y'}],
#                 'name': '1957'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1960]),
#                           'xaxis': 'x',
#                           'y': array([28.7]),
#                           'yaxis': 'y'}],
#                 'name': '1960'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1962, 1962]),
#                           'xaxis': 'x',
#                           'y': array([28. , 25.1]),
#                           'yaxis': 'y'}],
#                 'name': '1962'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1965, 1965]),
#                           'xaxis': 'x',
#                           'y': array([27.3, 23.7]),
#                           'yaxis': 'y'}],
#                 'name': '1965'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1963]),
#                           'xaxis': 'x',
#                           'y': array([24.3]),
#                           'yaxis': 'y'}],
#                 'name': '1963'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1964]),
#                           'xaxis': 'x',
#                           'y': array([24.2]),
#                           'yaxis': 'y'}],
#                 'name': '1964'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1967]),
#                           'xaxis': 'x',
#                           'y': array([25.9]),
#                           'yaxis': 'y'}],
#                 'name': '1967'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1968]),
#                           'xaxis': 'x',
#                           'y': array([24.7]),
#                           'yaxis': 'y'}],
#                 'name': '1968'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1969]),
#                           'xaxis': 'x',
#                           'y': array([24.8]),
#                           'yaxis': 'y'}],
#                 'name': '1969'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1970]),
#                           'xaxis': 'x',
#                           'y': array([24.9]),
#                           'yaxis': 'y'}],
#                 'name': '1970'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1971]),
#                           'xaxis': 'x',
#                           'y': array([24.4]),
#                           'yaxis': 'y'}],
#                 'name': '1971'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1972]),
#                           'xaxis': 'x',
#                           'y': array([23.1]),
#                           'yaxis': 'y'}],
#                 'name': '1972'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1973]),
#                           'xaxis': 'x',
#                           'y': array([21.9]),
#                           'yaxis': 'y'}],
#                 'name': '1973'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1974]),
#                           'xaxis': 'x',
#                           'y': array([22.7]),
#                           'yaxis': 'y'}],
#                 'name': '1974'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1975]),
#                           'xaxis': 'x',
#                           'y': array([21.4]),
#                           'yaxis': 'y'}],
#                 'name': '1975'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1976]),
#                           'xaxis': 'x',
#                           'y': array([21.7]),
#                           'yaxis': 'y'}],
#                 'name': '1976'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1978]),
#                           'xaxis': 'x',
#                           'y': array([23.7]),
#                           'yaxis': 'y'}],
#                 'name': '1978'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1979, 1979]),
#                           'xaxis': 'x',
#                           'y': array([24.8, 20.9]),
#                           'yaxis': 'y'}],
#                 'name': '1979'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1980]),
#                           'xaxis': 'x',
#                           'y': array([23.3]),
#                           'yaxis': 'y'}],
#                 'name': '1980'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1994, 1994, 1994]),
#                           'xaxis': 'x',
#                           'y': array([18.17, 18.2 , 17.8 ]),
#                           'yaxis': 'y'}],
#                 'name': '1994'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1995, 1995]),
#                           'xaxis': 'x',
#                           'y': array([18.3, 18.4]),
#                           'yaxis': 'y'}],
#                 'name': '1995'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1996, 1996]),
#                           'xaxis': 'x',
#                           'y': array([17.7, 18.5]),
#                           'yaxis': 'y'}],
#                 'name': '1996'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1997]),
#                           'xaxis': 'x',
#                           'y': array([17.2]),
#                           'yaxis': 'y'}],
#                 'name': '1997'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([1999]),
#                           'xaxis': 'x',
#                           'y': array([17.9]),
#                           'yaxis': 'y'}],
#                 'name': '1999'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2001]),
#                           'xaxis': 'x',
#                           'y': array([17.4]),
#                           'yaxis': 'y'}],
#                 'name': '2001'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2007]),
#                           'xaxis': 'x',
#                           'y': array([16.3]),
#                           'yaxis': 'y'}],
#                 'name': '2007'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2008, 2008, 2008]),
#                           'xaxis': 'x',
#                           'y': array([15.8, 15.6, 15.6]),
#                           'yaxis': 'y'}],
#                 'name': '2008'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2009, 2009]),
#                           'xaxis': 'x',
#                           'y': array([15.4, 15.2]),
#                           'yaxis': 'y'}],
#                 'name': '2009'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2012]),
#                           'xaxis': 'x',
#                           'y': array([15.3]),
#                           'yaxis': 'y'}],
#                 'name': '2012'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2014]),
#                           'xaxis': 'x',
#                           'y': array([14.1]),
#                           'yaxis': 'y'}],
#                 'name': '2014'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2015]),
#                           'xaxis': 'x',
#                           'y': array([14.]),
#                           'yaxis': 'y'}],
#                 'name': '2015'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2016, 2016]),
#                           'xaxis': 'x',
#                           'y': array([13.7, 13.6]),
#                           'yaxis': 'y'}],
#                 'name': '2016'},
#                {'data': [{'hovertemplate': 'Year=%{x}<br>GRS Length=%{y}<extra></extra>',
#                           'legendgroup': '',
#                           'marker': {'color': '#636efa', 'symbol': 'circle'},
#                           'mode': 'markers',
#                           'name': '',
#                           'orientation': 'v',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': array([2017, 2017, 2017]),
#                           'xaxis': 'x',
#                           'y': array([14. , 13.9, 14. ]),
#                           'yaxis': 'y'}],
#                 'name': '2017'}],
#     'layout': {'height': 520,
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'sliders': [{'active': 0,
#                             'currentvalue': {'prefix': 'Year='},
#                             'len': 0.9,
#                             'pad': {'b': 10, 't': 60},
#                             'steps': [{'args': [['1880'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1880',
#                                        'method': 'animate'},
#                                       {'args': [['1882'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1882',
#                                        'method': 'animate'},
#                                       {'args': [['1885'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1885',
#                                        'method': 'animate'},
#                                       {'args': [['1887'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1887',
#                                        'method': 'animate'},
#                                       {'args': [['1890'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1890',
#                                        'method': 'animate'},
#                                       {'args': [['1892'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1892',
#                                        'method': 'animate'},
#                                       {'args': [['1895'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1895',
#                                        'method': 'animate'},
#                                       {'args': [['1897'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
# ...
#                                                 'easing': 'linear'}}],
#                                        'label': '1968',
#                                        'method': 'animate'},
#                                       {'args': [['1969'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1969',
#                                        'method': 'animate'},
#                                       {'args': [['1970'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1970',
#                                        'method': 'animate'},
#                                       {'args': [['1971'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1971',
#                                        'method': 'animate'},
#                                       {'args': [['1972'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1972',
#                                        'method': 'animate'},
#                                       {'args': [['1973'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1973',
#                                        'method': 'animate'},
#                                       {'args': [['1974'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1974',
#                                        'method': 'animate'},
#                                       {'args': [['1975'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1975',
#                                        'method': 'animate'},
#                                       {'args': [['1976'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1976',
#                                        'method': 'animate'},
#                                       {'args': [['1978'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1978',
#                                        'method': 'animate'},
#                                       {'args': [['1979'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1979',
#                                        'method': 'animate'},
#                                       {'args': [['1980'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1980',
#                                        'method': 'animate'},
#                                       {'args': [['1994'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1994',
#                                        'method': 'animate'},
#                                       {'args': [['1995'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1995',
#                                        'method': 'animate'},
#                                       {'args': [['1996'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1996',
#                                        'method': 'animate'},
#                                       {'args': [['1997'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1997',
#                                        'method': 'animate'},
#                                       {'args': [['1999'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '1999',
#                                        'method': 'animate'},
#                                       {'args': [['2001'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2001',
#                                        'method': 'animate'},
#                                       {'args': [['2007'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2007',
#                                        'method': 'animate'},
#                                       {'args': [['2008'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2008',
#                                        'method': 'animate'},
#                                       {'args': [['2009'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2009',
#                                        'method': 'animate'},
#                                       {'args': [['2012'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2012',
#                                        'method': 'animate'},
#                                       {'args': [['2014'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2014',
#                                        'method': 'animate'},
#                                       {'args': [['2015'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2015',
#                                        'method': 'animate'},
#                                       {'args': [['2016'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2016',
#                                        'method': 'animate'},
#                                       {'args': [['2017'], {'frame': {'duration':
#                                                 0, 'redraw': False}, 'mode':
#                                                 'immediate', 'fromcurrent': True,
#                                                 'transition': {'duration': 0,
#                                                 'easing': 'linear'}}],
#                                        'label': '2017',
#                                        'method': 'animate'}],
#                             'x': 0.1,
#                             'xanchor': 'left',
#                             'y': 0,
#                             'yanchor': 'top'}],
#                'template': '...',
#                'title': {'text': 'Great Red Spot Size Animation', 'x': 0.5, 'y': 0.94},
#                'updatemenus': [{'buttons': [{'args': [None, {'frame': {'duration':
#                                                       200, 'redraw': False},
#                                                       'mode': 'immediate',
#                                                       'fromcurrent': True,
#                                                       'transition': {'duration':
#                                                       500, 'easing': 'linear'}}],
#                                              'label': '&#9654;',
#                                              'method': 'animate'},
#                                             {'args': [[None], {'frame':
#                                                       {'duration': 0, 'redraw':
#                                                       False}, 'mode': 'immediate',
#                                                       'fromcurrent': True,
#                                                       'transition': {'duration': 0,
#                                                       'easing': 'linear'}}],
#                                              'label': '&#9724;',
#                                              'method': 'animate'}],
#                                 'direction': 'left',
#                                 'pad': {'r': 10, 't': 70},
#                                 'showactive': False,
#                                 'type': 'buttons',
#                                 'x': 0.1,
#                                 'xanchor': 'right',
#                                 'y': 0,
#                                 'yanchor': 'top'}],
#                'width': 600,
#                'xaxis': {'anchor': 'y',
#                          'categoryarray': [1880, 1882, 1885, 1887, 1890, 1892,
#                                            1895, 1897, 1900, 1902, 1905, 1907,
#                                            1910, 1912, 1915, 1917, 1920, 1922,
#                                            1925, 1927, 1930, 1932, 1935, 1937,
#                                            1940, 1942, 1945, 1947, 1950, 1952,
#                                            1955, 1957, 1960, 1962, 1965, 1963,
#                                            1964, 1967, 1968, 1969, 1970, 1971,
#                                            1972, 1973, 1974, 1975, 1976, 1978,
#                                            1979, 1980, 1994, 1995, 1996, 1997,
#                                            1999, 2001, 2007, 2008, 2009, 2012,
#                                            2014, 2015, 2016, 2017],
#                          'categoryorder': 'array',
#                          'domain': [0.0, 1.0],
#                          'range': [1870, 2030],
#                          'title': {'text': 'Year'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'range': [10, 40], 'title': {'text': 'GRS Length'}}}
# })
