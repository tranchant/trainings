# %% [markdown]
# # Plot somme basis plots with `python` and `matplot` library

# %%
# %cat /ifb/data/mydatalocal/stat-merged.csv
# Out:
# sample,reads,len,len_mean,qual_mean, total_bases
# Clone10-LR,20000,8294.3039,12.0000,165886079
# Clone11-LR,20000,8330.4306,12.0000,166608612
# Clone12-LR,20000,8358.5272,12.0000,167170544
# Clone13-LR,20000,8344.3858,12.0000,166887716
# Clone14-LR,20000,8340.0313,12.0000,166800626
# Clone15-LR,20000,8426.4577,12.0000,168529154
# Clone1-LR,20000,8173.2053,12.0000,163464106
# Clone2-LR,20000,8368.8738,12.0000,167377475
# Clone3-LR,20000,8290.8154,12.0000,165816308
# Clone4-LR,20000,8246.4397,12.0000,164928793
# Clone5-LR,20000,8352.3097,12.0000,167046194
# Clone6-LR,20000,8191.4234,12.0000,163828467
# Clone7-LR,20000,8366.2169,12.0000,167324339
# Clone8-LR,20000,8266.7213,12.0000,165334427
# Clone9-LR,20000,8363.9497,12.0000,167278995

# %% [markdown]
# #### Put the correct file name of your csv file generated previously with the python script

# %%
csv_file="/ifb/data/mydatalocal/stat-merged.csv"

# Load the csv file into a python/panda dataframe
df1 = pd.read_csv(csv_file, index_col=False)

# %% [markdown]
# #### Plot the reads number by fastq file

# %%
# Define the size of the figure
plt.figure(figsize=(20, 5))
ax = plt.gca()

df1.plot(x='sample', y='reads',kind="bar", color='blue', ax=ax, linewidth=3)
plt.title('PUT YOUR TITLE', fontsize=10)
plt.xlabel('PUT X LABEL')
plt.ylabel('PUT Y LABEL')
plt.xticks(
        rotation=45,
        horizontalalignment='right',
        fontweight='light',
        fontsize='8',
    )

plt.show()

# %% [markdown]
# #### Plot the length mean

# %%
# Define the size of the figure
plt.figure(figsize=(8, 5))
ax = plt.gca()

#dot plot of the mean length by file
df1.plot(x='sample', y='len',kind="scatter", color='blue', ax=ax, linewidth=3)
df1.plot(x='sample', y='len_mean',kind="scatter", color='forestgreen', ax=ax, linewidth=3)
plt.title('PUT YOUR TITLE', fontsize=10)
plt.xlabel('PUT X LABEL')
plt.ylabel('PUT Y LABEL')
plt.xticks(
        rotation=45,
        horizontalalignment='right',
        fontweight='light',
        fontsize='8',
    )
plt.show()

# %% [markdown]
# #### EXERCICE
#
# * 1 - Plot the total_base column (barplot)
# * 2 - Plot the total_base qual-mean (dot plot)
